# %%
include("../src/industrial_stats.jl")
using .IndustrialStats: CEXCH, DesignInitializer, ModelBuilder

# %%
using Random
using Distributions

# %%
seed = 42
rng = MersenneTwister(seed)
# Out:
# MersenneTwister(42)

# %%
model_builder = ModelBuilder.scheffe(1)
init = DesignInitializer.make_initializer(7, 3, model_builder; type="mixture", rng=rng)
# Out:
# #12 (generic function with 1 method)

# %%
init(100)
# Out:
# 100×7×3 Array{Float64, 3}:
# [:, :, 1] =
#  0.0618907   0.663839   0.293487   …  0.425989    0.577196    0.303805
#  0.607871    0.231017   0.228298      0.120747    0.0677242   0.505368
#  0.330238    0.559631   0.657294      0.258296    0.795121    0.190828
#  0.187077    0.367777   0.114408      0.00560769  0.137155    0.517699
#  0.0861567   0.0725917  0.553974      0.736096    0.0706053   0.21079
#  0.726766    0.0488546  0.329537   …  0.264723    0.189048    0.271511
#  0.32979     0.356009   0.116488      0.129994    0.740347    0.609167
#  0.528534    0.595136   0.1624        0.605283    0.224507    0.36906
#  0.141676    0.565888   0.0785949     0.024151    0.330962    0.021773
#  0.542126    0.365744   0.759005      0.221613    0.444531    0.544458
#  0.216867    0.0683678  0.473107   …  0.754236    0.118293    0.178025
#  0.241007    0.164054   0.45349       0.169435    0.439003    0.277517
#  0.319426    0.753839   0.0734029     0.50439     0.442704    0.235345
# ...
